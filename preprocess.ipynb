# %%
options(timeout = 600)
download.file("https://bmblx.bmi.osumc.edu/ssread_download/scrnaseq_qsave/AD00104.qsave",
              destfile = "AD00104.qsave",
              method = "curl",
              mode = "wb")

# %%
install.packages("qs")
install.packages("Seurat")
install.packages("remotes")
remotes::install_github("mojaveazure/seurat-disk")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Skipping install of 'SeuratDisk' from a github remote, the SHA1 (877d4e18) has not changed since last install.
#   Use `force = TRUE` to force installation

# %%
data_obj <- qs::qread("/content/AD00104.qsave")
data_obj
# Out:
# An object of class Seurat
# 26513 features across 8283 samples within 1 assay
# Active assay: RNA (26513 features, 2000 variable features)
#  2 layers present: data, scale.data
#  3 dimensional reductions calculated: pca, harmony, umap

# %%
head(data_obj@meta.data)
# Out:
#                    orig.ident nCount_RNA nFeature_RNA RNA_snn_res.0.8
# AAACCTGAGGCGATAC.4 all        2747.035   1460         NA
# AAACCTGTCGAGAGCA.4 all        1543.702    539         NA
# AAACCTGTCTATGTGG.4 all        3210.611   2017         NA
# AAACGGGCAAATCCGT.4 all        1998.975    849         NA
# AAACGGGGTCTTCGTC.4 all        3755.120   3084         NA
# AAACGGGGTGCAGACA.4 all        4273.944   4974         NA
#                    seurat_clusters marker_cell_type scina_cell_type
# AAACCTGAGGCGATAC.4 9               NA               NA
# AAACCTGTCGAGAGCA.4 0               NA               NA
# AAACCTGTCTATGTGG.4 16              NA               NA
# AAACGGGCAAATCCGT.4 29              NA               NA
# AAACGGGGTCTTCGTC.4 49              NA               NA
# AAACGGGGTGCAGACA.4 3               NA               NA
#                    predicted.id       group   RNA_snn_res.4 ⋯
# AAACCTGAGGCGATAC.4 Astrocytes         disease 9             ⋯
# ...

# %%
head(data_obj@assays$RNA@data)
# Out:
#   [[ suppressing 8283 column names ‘AAACCTGAGGCGATAC.4’, ‘AAACCTGTCGAGAGCA.4’, ‘AAACCTGTCTATGTGG.4’ ... ]]
# 6 x 8283 sparse Matrix of class "dgCMatrix"
#
# A1BG     . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# A1BG-AS1 . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# A1CF     . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# A2M      . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# A2M-AS1  . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# A2ML1    . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
#
# A1BG     . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# A1BG-AS1 . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# A1CF     . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# A2M      . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# ...

# %%
head(data_obj@assays$RNA@scale.data)
# Out:
#          AAACCTGAGGCGATAC.4 AAACCTGTCGAGAGCA.4 AAACCTGTCTATGTGG.4
# A1BG     -0.14049981        -0.14049981        -0.14049981
# A1BG-AS1 -0.22650614        -0.22650614        -0.22650614
# A1CF     -0.04999205        -0.04999205        -0.04999205
# A2M      -0.10067604        -0.10067604        -0.10067604
# A2M-AS1  -0.08277035        -0.08277035        -0.08277035
# A2ML1    -0.13525075        -0.13525075        -0.13525075
#          AAACGGGCAAATCCGT.4 AAACGGGGTCTTCGTC.4 AAACGGGGTGCAGACA.4
# A1BG     -0.14049981        -0.14049981        -0.14049981
# A1BG-AS1 -0.22650614        -0.22650614         2.15866616
# A1CF     -0.04999205        -0.04999205        -0.04999205
# A2M      -0.10067604        -0.10067604        -0.10067604
# A2M-AS1  -0.08277035         7.92794192        -0.08277035
# A2ML1    -0.13525075        -0.13525075        -0.13525075
#          AAAGATGGTTGTACAC.4 AAAGATGTCAACGGCC.4 AAAGCAAGTCCAACTA.4
# A1BG     -0.14049981        -0.14049981        -0.14049981
# ...

# %%
head(data_obj@reductions$umap@cell.embeddings)
# Out:
#                    UMAP_1     UMAP_2
# AAACCTGAGGCGATAC.4   2.966027 -10.542658789
# AAACCTGTCGAGAGCA.4 -11.547598  -0.007180197
# AAACCTGTCTATGTGG.4  -2.022753   0.640587824
# AAACGGGCAAATCCGT.4 -12.164813   0.455470579
# AAACGGGGTCTTCGTC.4   7.443958  -1.742941362
# AAACGGGGTGCAGACA.4   7.558183   1.493962305

# %%
slotNames(data_obj)
# Out:
#  [1] "assays"       "meta.data"    "active.assay" "active.ident" "graphs"
#  [6] "neighbors"    "reductions"   "images"       "project.name" "misc"
# [11] "version"      "commands"     "tools"

# %%
library(Seurat)
library(SeuratDisk)

# convert Seurat to h5ad
SaveH5Seurat(data_obj, filename = "seurat_data.h5Seurat", overwrite = TRUE)
Convert("seurat_data.h5Seurat", dest = "h5ad", overwrite = TRUE)
# Out:
# Warning message:
# “Overwriting previous file seurat_data.h5Seurat”
# Creating h5Seurat file for version 3.1.5.9900
#
# Adding data for RNA
#
# Adding scale.data for RNA
#
# Adding variable features for RNA
#
# Adding feature-level metadata for RNA
#
# Adding cell embeddings for pca
#
# Adding loadings for pca
#
# No projected loadings for pca
#
# Adding standard deviations for pca
#
# No JackStraw data for pca
#
# Adding cell embeddings for harmony
#
# Adding loadings for harmony
#
# Adding projected loadings for harmony
#
# Adding standard deviations for harmony
#
# No JackStraw data for harmony
#
# Adding cell embeddings for umap
#
# No loadings for umap
#
# No projected loadings for umap
#
# No standard deviations for umap
#
# No JackStraw data for umap
#
# Validating h5Seurat file
#
# Adding scale.data from RNA as X
#
# Transfering meta.features to var
#
# Adding data from RNA as raw
#
# Transfering meta.features to raw/var
#
# Transfering meta.data to obs
#
# ...
